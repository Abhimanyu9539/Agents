# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from langchain_community.tools import TavilySearchResults
from typing import TypedDict, Annotated
from langgraph.graph import add_messages, StateGraph, END
from dotenv import load_dotenv
from langgraph.prebuilt import ToolNode

load_dotenv()

class AgentState(TypedDict):
    messages: Annotated[list, add_messages]

search_tool = TavilySearchResults(max_results=2)
tools = [search_tool]

llm = ChatOpenAI(model="gpt-4o")
llm_with_tools = llm.bind_tools(tools=tools)

def model(state: AgentState):
    return {
        "messages": [llm_with_tools.invoke(state["messages"])], 
    }

def tools_router(state: AgentState):
    last_message = state["messages"][-1]

    if(hasattr(last_message, "tool_calls") and len(last_message.tool_calls) > 0):
        return "tool_node"
    else: 
        return END
    

tool_node = ToolNode(tools=tools)

graph = StateGraph(AgentState)

graph.add_node("model", model)
graph.add_node("tool_node", tool_node)
graph.set_entry_point("model")

graph.add_conditional_edges("model", tools_router)
graph.add_edge("tool_node", "model")

app = graph.compile()

# %%
from IPython.display import Image, display
from langchain_core.runnables.graph import MermaidDrawMethod

display(
    Image(
        app.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API
        )
    )
)

# %%
input = {
    "messages": ["What's the current weather in Bangalore?"]
}

events = app.stream(input=input, stream_mode="values")

for event in events: 
    print(event["messages"])
# Out:
# [HumanMessage(content="What's the current weather in Bangalore?", additional_kwargs={}, response_metadata={}, id='0fa87a72-ef2d-4084-a0f0-6abb24a91319')]
# [HumanMessage(content="What's the current weather in Bangalore?", additional_kwargs={}, response_metadata={}, id='0fa87a72-ef2d-4084-a0f0-6abb24a91319'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_IxhTUoFH83qBla1Kv4m8ruML', 'function': {'arguments': '{"query":"current weather in Bangalore"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 86, 'total_tokens': 108, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f5bdcc3276', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-18664493-0e85-4e12-9f93-dd1f4e68132f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Bangalore'}, 'id': 'call_IxhTUoFH83qBla1Kv4m8ruML', 'type': 'tool_call'}], usage_metadata={'input_tokens': 86, 'output_tokens': 22, 'total_tokens': 108, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]
# [HumanMessage(content="What's the current weather in Bangalore?", additional_kwargs={}, response_metadata={}, id='0fa87a72-ef2d-4084-a0f0-6abb24a91319'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_IxhTUoFH83qBla1Kv4m8ruML', 'function': {'arguments': '{"query":"current weather in Bangalore"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 86, 'total_tokens': 108, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f5bdcc3276', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-18664493-0e85-4e12-9f93-dd1f4e68132f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Bangalore'}, 'id': 'call_IxhTUoFH83qBla1Kv4m8ruML', 'type': 'tool_call'}], usage_metadata={'input_tokens': 86, 'output_tokens': 22, 'total_tokens': 108, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='[{"url": "https://www.weatherapi.com/", "content": "{\'location\': {\'name\': \'Bangalore\', \'region\': \'Karnataka\', \'country\': \'India\', \'lat\': 12.9833, \'lon\': 77.5833, \'tz_id\': \'Asia/Kolkata\', \'localtime_epoch\': 1745213542, \'localtime\': \'2025-04-21 11:02\'}, \'current\': {\'last_updated_epoch\': 1745213400, \'last_updated\': \'2025-04-21 11:00\', \'temp_c\': 30.1, \'temp_f\': 86.2, \'is_day\': 1, \'condition\': {\'text\': \'Sunny\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/113.png\', \'code\': 1000}, \'wind_mph\': 8.7, \'wind_kph\': 14.0, \'wind_degree\': 94, \'wind_dir\': \'E\', \'pressure_mb\': 1017.0, \'pressure_in\': 30.03, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 59, \'cloud\': 25, \'feelslike_c\': 28.6, \'feelslike_f\': 83.5, \'windchill_c\': 33.1, \'windchill_f\': 91.5, \'heatindex_c\': 32.0, \'heatindex_f\': 89.6, \'dewpoint_c\': 11.4, \'dewpoint_f\': 52.5, \'vis_km\': 6.0, \'vis_miles\': 3.0, \'uv\': 10.7, \'gust_mph\': 10.0, \'gust_kph\': 16.2}}"}, {"url": "https://www.easeweather.com/asia/india/karnataka/bangalore-urban/april", "content": "| --- | --- | --- | --- | --- | --- |\\n| 1 Apr. | \\nSunny\\n| 34° /21° | 0\xa0mm | 8 |  |\\n| 2 Apr. | \\nSunny\\n| 35° /22° | 0\xa0mm | 9 |  |\\n| 3 Apr. | \\nModerate rain\\n| 31° /22° | 12.4\xa0mm | 2.1 |  |\\n| 4 Apr. | \\nPatchy rain possible\\n| 31° /23° | 0.4\xa0mm | 2.4 |  |\\n| 5 Apr. | \\nModerate rain\\n| 30° /24° | 6\xa0mm | 2.6 |  |\\n| 6 Apr. | \\nModerate rain\\n| 32° /22° | 8.2\xa0mm | 3.4 |  |\\n| 7 Apr. | \\nPartly cloudy\\n| 35° /23° | 0\xa0mm | 7 |  |\\n| 8 Apr. | \\nSunny\\n| 36° /25° | 0\xa0mm | 7 |  |\\n| 9 Apr. | \\nPatchy rain possible [...] | 35° /24° | 1.2\xa0mm | 6 |  |\\n| 10 Apr. | \\nPartly cloudy\\n| 33° /24° | 0.1\xa0mm | 7 |  |\\n| 11 Apr. | \\nPatchy rain possible\\n| 33° /23° | 0.2\xa0mm | 6 |  |\\n| 12 Apr. | \\nPatchy rain possible\\n| 33° /22° | 0.3\xa0mm | 6 |  |\\n| 13 Apr. | \\nSunny\\n| 35° /24° | 0\xa0mm | 7 |  |\\n| 14 Apr. | \\nSunny\\n| 35° /26° | 0\xa0mm | 8 |  |\\n| 15 Apr. | \\nSunny\\n| 35° /25° | 0\xa0mm | 7 |  |\\n| 16 Apr. | \\nSunny\\n| 36° /21° | 0\xa0mm | 9 |  |\\n| 17 Apr. | \\nSunny\\n| 37° /22° | 0\xa0mm | 9 |  |\\n| 18 Apr. | \\nSunny\\n| 37° /22° | 1.1\xa0mm | 9 |  | [...] April\\nJanuaryFebruaryMarch\\nApril\\nMayJuneJulyAugustSeptemberOctoberNovemberDecember\\nWeather in Bangalore Urban for April 2025\\nYour guide to Bangalore Urban weather in April - trends and predictions\\nTemperatures\\n\\n\\nThe forecast for the next days in Bangalore Urban predicts temperatures to be around 33\xa0°C, close to the historical average."}]', name='tavily_search_results_json', id='8a84632f-9f1f-4450-bdc7-eeb8d4a38566', tool_call_id='call_IxhTUoFH83qBla1Kv4m8ru ...
# [HumanMessage(content="What's the current weather in Bangalore?", additional_kwargs={}, response_metadata={}, id='0fa87a72-ef2d-4084-a0f0-6abb24a91319'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_IxhTUoFH83qBla1Kv4m8ruML', 'function': {'arguments': '{"query":"current weather in Bangalore"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 86, 'total_tokens': 108, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f5bdcc3276', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-18664493-0e85-4e12-9f93-dd1f4e68132f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Bangalore'}, 'id': 'call_IxhTUoFH83qBla1Kv4m8ruML', 'type': 'tool_call'}], usage_metadata={'input_tokens': 86, 'output_tokens': 22, 'total_tokens': 108, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='[{"url": "https://www.weatherapi.com/", "content": "{\'location\': {\'name\': \'Bangalore\', \'region\': \'Karnataka\', \'country\': \'India\', \'lat\': 12.9833, \'lon\': 77.5833, \'tz_id\': \'Asia/Kolkata\', \'localtime_epoch\': 1745213542, \'localtime\': \'2025-04-21 11:02\'}, \'current\': {\'last_updated_epoch\': 1745213400, \'last_updated\': \'2025-04-21 11:00\', \'temp_c\': 30.1, \'temp_f\': 86.2, \'is_day\': 1, \'condition\': {\'text\': \'Sunny\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/113.png\', \'code\': 1000}, \'wind_mph\': 8.7, \'wind_kph\': 14.0, \'wind_degree\': 94, \'wind_dir\': \'E\', \'pressure_mb\': 1017.0, \'pressure_in\': 30.03, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 59, \'cloud\': 25, \'feelslike_c\': 28.6, \'feelslike_f\': 83.5, \'windchill_c\': 33.1, \'windchill_f\': 91.5, \'heatindex_c\': 32.0, \'heatindex_f\': 89.6, \'dewpoint_c\': 11.4, \'dewpoint_f\': 52.5, \'vis_km\': 6.0, \'vis_miles\': 3.0, \'uv\': 10.7, \'gust_mph\': 10.0, \'gust_kph\': 16.2}}"}, {"url": "https://www.easeweather.com/asia/india/karnataka/bangalore-urban/april", "content": "| --- | --- | --- | --- | --- | --- |\\n| 1 Apr. | \\nSunny\\n| 34° /21° | 0\xa0mm | 8 |  |\\n| 2 Apr. | \\nSunny\\n| 35° /22° | 0\xa0mm | 9 |  |\\n| 3 Apr. | \\nModerate rain\\n| 31° /22° | 12.4\xa0mm | 2.1 |  |\\n| 4 Apr. | \\nPatchy rain possible\\n| 31° /23° | 0.4\xa0mm | 2.4 |  |\\n| 5 Apr. | \\nModerate rain\\n| 30° /24° | 6\xa0mm | 2.6 |  |\\n| 6 Apr. | \\nModerate rain\\n| 32° /22° | 8.2\xa0mm | 3.4 |  |\\n| 7 Apr. | \\nPartly cloudy\\n| 35° /23° | 0\xa0mm | 7 |  |\\n| 8 Apr. | \\nSunny\\n| 36° /25° | 0\xa0mm | 7 |  |\\n| 9 Apr. | \\nPatchy rain possible [...] | 35° /24° | 1.2\xa0mm | 6 |  |\\n| 10 Apr. | \\nPartly cloudy\\n| 33° /24° | 0.1\xa0mm | 7 |  |\\n| 11 Apr. | \\nPatchy rain possible\\n| 33° /23° | 0.2\xa0mm | 6 |  |\\n| 12 Apr. | \\nPatchy rain possible\\n| 33° /22° | 0.3\xa0mm | 6 |  |\\n| 13 Apr. | \\nSunny\\n| 35° /24° | 0\xa0mm | 7 |  |\\n| 14 Apr. | \\nSunny\\n| 35° /26° | 0\xa0mm | 8 |  |\\n| 15 Apr. | \\nSunny\\n| 35° /25° | 0\xa0mm | 7 |  |\\n| 16 Apr. | \\nSunny\\n| 36° /21° | 0\xa0mm | 9 |  |\\n| 17 Apr. | \\nSunny\\n| 37° /22° | 0\xa0mm | 9 |  |\\n| 18 Apr. | \\nSunny\\n| 37° /22° | 1.1\xa0mm | 9 |  | [...] April\\nJanuaryFebruaryMarch\\nApril\\nMayJuneJulyAugustSeptemberOctoberNovemberDecember\\nWeather in Bangalore Urban for April 2025\\nYour guide to Bangalore Urban weather in April - trends and predictions\\nTemperatures\\n\\n\\nThe forecast for the next days in Bangalore Urban predicts temperatures to be around 33\xa0°C, close to the historical average."}]', name='tavily_search_results_json', id='8a84632f-9f1f-4450-bdc7-eeb8d4a38566', tool_call_id='call_IxhTUoFH83qBla1Kv4m8ru ...

# %%
input = {
    "messages": ["What's the current weather in Bangalore?"]
}

events = app.stream(input=input, stream_mode="updates")

for event in events: 
    print(event)
# Out:
# {'model': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_x5Yo5tYmif8DBqSoWxaxQ393', 'function': {'arguments': '{"query":"current weather in Bangalore"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 86, 'total_tokens': 108, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f5bdcc3276', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-7fca5406-6e8a-44a6-a586-f8a0a3553849-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Bangalore'}, 'id': 'call_x5Yo5tYmif8DBqSoWxaxQ393', 'type': 'tool_call'}], usage_metadata={'input_tokens': 86, 'output_tokens': 22, 'total_tokens': 108, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# {'tool_node': {'messages': [ToolMessage(content='[{"url": "https://www.weatherapi.com/", "content": "{\'location\': {\'name\': \'Bangalore\', \'region\': \'Karnataka\', \'country\': \'India\', \'lat\': 12.9833, \'lon\': 77.5833, \'tz_id\': \'Asia/Kolkata\', \'localtime_epoch\': 1745213542, \'localtime\': \'2025-04-21 11:02\'}, \'current\': {\'last_updated_epoch\': 1745213400, \'last_updated\': \'2025-04-21 11:00\', \'temp_c\': 30.1, \'temp_f\': 86.2, \'is_day\': 1, \'condition\': {\'text\': \'Sunny\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/113.png\', \'code\': 1000}, \'wind_mph\': 8.7, \'wind_kph\': 14.0, \'wind_degree\': 94, \'wind_dir\': \'E\', \'pressure_mb\': 1017.0, \'pressure_in\': 30.03, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 59, \'cloud\': 25, \'feelslike_c\': 28.6, \'feelslike_f\': 83.5, \'windchill_c\': 33.1, \'windchill_f\': 91.5, \'heatindex_c\': 32.0, \'heatindex_f\': 89.6, \'dewpoint_c\': 11.4, \'dewpoint_f\': 52.5, \'vis_km\': 6.0, \'vis_miles\': 3.0, \'uv\': 10.7, \'gust_mph\': 10.0, \'gust_kph\': 16.2}}"}, {"url": "https://www.easeweather.com/asia/india/karnataka/bangalore-urban/april", "content": "| --- | --- | --- | --- | --- | --- |\\n| 1 Apr. | \\nSunny\\n| 34° /21° | 0\xa0mm | 8 |  |\\n| 2 Apr. | \\nSunny\\n| 35° /22° | 0\xa0mm | 9 |  |\\n| 3 Apr. | \\nModerate rain\\n| 31° /22° | 12.4\xa0mm | 2.1 |  |\\n| 4 Apr. | \\nPatchy rain possible\\n| 31° /23° | 0.4\xa0mm | 2.4 |  |\\n| 5 Apr. | \\nModerate rain\\n| 30° /24° | 6\xa0mm | 2.6 |  |\\n| 6 Apr. | \\nModerate rain\\n| 32° /22° | 8.2\xa0mm | 3.4 |  |\\n| 7 Apr. | \\nPartly cloudy\\n| 35° /23° | 0\xa0mm | 7 |  |\\n| 8 Apr. | \\nSunny\\n| 36° /25° | 0\xa0mm | 7 |  |\\n| 9 Apr. | \\nPatchy rain possible [...] | 35° /24° | 1.2\xa0mm | 6 |  |\\n| 10 Apr. | \\nPartly cloudy\\n| 33° /24° | 0.1\xa0mm | 7 |  |\\n| 11 Apr. | \\nPatchy rain possible\\n| 33° /23° | 0.2\xa0mm | 6 |  |\\n| 12 Apr. | \\nPatchy rain possible\\n| 33° /22° | 0.3\xa0mm | 6 |  |\\n| 13 Apr. | \\nSunny\\n| 35° /24° | 0\xa0mm | 7 |  |\\n| 14 Apr. | \\nSunny\\n| 35° /26° | 0\xa0mm | 8 |  |\\n| 15 Apr. | \\nSunny\\n| 35° /25° | 0\xa0mm | 7 |  |\\n| 16 Apr. | \\nSunny\\n| 36° /21° | 0\xa0mm | 9 |  |\\n| 17 Apr. | \\nSunny\\n| 37° /22° | 0\xa0mm | 9 |  |\\n| 18 Apr. | \\nSunny\\n| 37° /22° | 1.1\xa0mm | 9 |  | [...] April\\nJanuaryFebruaryMarch\\nApril\\nMayJuneJulyAugustSeptemberOctoberNovemberDecember\\nWeather in Bangalore Urban for April 2025\\nYour guide to Bangalore Urban weather in April - trends and predictions\\nTemperatures\\n\\n\\nThe forecast for the next days in Bangalore Urban predicts temperatures to be around 33\xa0°C, close to the historical average."}]', name='tavily_search_results_json', id='09088ae3-764d-4ab4-8ea0-bbaa32d455af', tool_call_id='call_x5Yo5tYmif8DBqSoWxaxQ393', artifact={'query': 'current weather in Bangalore', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'title': 'Weather in Bangalore', 'url': 'https://www.weatherapi.com/', 'content': "{'location': {'name': 'Bangalore', 'region': 'Karnataka', 'country': 'India', 'lat': 12.9833, 'lon': 77.5833, 'tz_id': 'Asia/Kolkata', 'localtime_epoch': 1745213542, 'localtime': '2025-04-21 11:02'}, 'current': {'last_updated_epoch': 1745213400, 'last_updated': '2025-04-21 11:00', 'temp_c': 30.1, 'temp_f': 86.2, 'is_day': 1, 'condition': {'text': 'Sunny', 'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png', 'code': 1000}, 'wind_mph': 8.7, 'wind_kph': 14.0, 'wind_degree': 94, 'wind_dir': 'E', 'pressure_mb': 1017.0, 'pressure_in': 30.03, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 59, 'cloud': 25, 'feelslike_c': 28.6, 'feelslike_f': 83.5, 'windchill_c': 33.1, 'windchill_f': 91.5, 'heatindex_c': 32.0, 'heatindex_f': 89.6, 'dewpoint_c': 11.4, 'dewpoint_f': 52.5, 'vis_km': 6.0, 'vis_miles': 3.0, 'uv': 10.7, 'gust_mph': 10.0, 'gust_kph': 16.2}}", 'score': 0.9382876, 'raw_content': None}, {'url': 'https://www.easeweather.com/asia/india/karnataka/bangalore-urban/april', 'title' ...
# {'model': {'messages': [AIMessage(content="The current weather in Bangalore is sunny with a temperature of 30.1°C (86.2°F). The wind is blowing from the east at a speed of 14.0 kph (8.7 mph), and the humidity level is at 59%. The visibility is 6.0 km, and there's no precipitation currently.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 71, 'prompt_tokens': 1201, 'total_tokens': 1272, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f5bdcc3276', 'finish_reason': 'stop', 'logprobs': None}, id='run-f8671141-4695-4dc3-a598-b255735c7eac-0', usage_metadata={'input_tokens': 1201, 'output_tokens': 71, 'total_tokens': 1272, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}

# %%
input = {
    "messages": ["Hi, how are you?"]
}

events = app.astream_events(input=input, version="v2")

async for event in events: 
    print(event)
# Out:
# {'event': 'on_chain_start', 'data': {'input': {'messages': ['Hi, how are you?']}}, 'name': 'LangGraph', 'tags': [], 'run_id': '9f8df4a1-aa65-4bd2-8a31-0bca8171434e', 'metadata': {}, 'parent_ids': []}
# {'event': 'on_chain_start', 'data': {'input': {'messages': ['Hi, how are you?']}}, 'name': '__start__', 'tags': ['graph:step:0', 'langsmith:hidden'], 'run_id': '2fcaf41c-e494-4806-9e4c-b589da9ddb60', 'metadata': {'langgraph_step': 0, 'langgraph_node': '__start__', 'langgraph_triggers': ('__start__',), 'langgraph_path': ('__pregel_pull', '__start__'), 'langgraph_checkpoint_ns': '__start__:b9f9fe35-1986-2a67-1275-6802f72ceba5'}, 'parent_ids': ['9f8df4a1-aa65-4bd2-8a31-0bca8171434e']}
# {'event': 'on_chain_start', 'data': {'input': {'messages': ['Hi, how are you?']}}, 'name': '_write', 'tags': ['seq:step:1', 'langsmith:hidden', 'langsmith:hidden'], 'run_id': 'ca48811c-18b1-4e82-835e-849b47163f16', 'metadata': {'langgraph_step': 0, 'langgraph_node': '__start__', 'langgraph_triggers': ('__start__',), 'langgraph_path': ('__pregel_pull', '__start__'), 'langgraph_checkpoint_ns': '__start__:b9f9fe35-1986-2a67-1275-6802f72ceba5'}, 'parent_ids': ['9f8df4a1-aa65-4bd2-8a31-0bca8171434e', '2fcaf41c-e494-4806-9e4c-b589da9ddb60']}
# {'event': 'on_chain_end', 'data': {'output': {'messages': ['Hi, how are you?']}, 'input': {'messages': ['Hi, how are you?']}}, 'run_id': 'ca48811c-18b1-4e82-835e-849b47163f16', 'name': '_write', 'tags': ['seq:step:1', 'langsmith:hidden', 'langsmith:hidden'], 'metadata': {'langgraph_step': 0, 'langgraph_node': '__start__', 'langgraph_triggers': ('__start__',), 'langgraph_path': ('__pregel_pull', '__start__'), 'langgraph_checkpoint_ns': '__start__:b9f9fe35-1986-2a67-1275-6802f72ceba5'}, 'parent_ids': ['9f8df4a1-aa65-4bd2-8a31-0bca8171434e', '2fcaf41c-e494-4806-9e4c-b589da9ddb60']}
# {'event': 'on_chain_start', 'data': {'input': {'messages': ['Hi, how are you?']}}, 'name': '_write', 'tags': ['seq:step:3', 'langsmith:hidden', 'langsmith:hidden'], 'run_id': 'fa5ae79f-31dd-4db8-afb2-6b74439d10c3', 'metadata': {'langgraph_step': 0, 'langgraph_node': '__start__', 'langgraph_triggers': ('__start__',), 'langgraph_path': ('__pregel_pull', '__start__'), 'langgraph_checkpoint_ns': '__start__:b9f9fe35-1986-2a67-1275-6802f72ceba5'}, 'parent_ids': ['9f8df4a1-aa65-4bd2-8a31-0bca8171434e', '2fcaf41c-e494-4806-9e4c-b589da9ddb60']}
# {'event': 'on_chain_end', 'data': {'output': {'messages': ['Hi, how are you?']}, 'input': {'messages': ['Hi, how are you?']}}, 'run_id': 'fa5ae79f-31dd-4db8-afb2-6b74439d10c3', 'name': '_write', 'tags': ['seq:step:3', 'langsmith:hidden', 'langsmith:hidden'], 'metadata': {'langgraph_step': 0, 'langgraph_node': '__start__', 'langgraph_triggers': ('__start__',), 'langgraph_path': ('__pregel_pull', '__start__'), 'langgraph_checkpoint_ns': '__start__:b9f9fe35-1986-2a67-1275-6802f72ceba5'}, 'parent_ids': ['9f8df4a1-aa65-4bd2-8a31-0bca8171434e', '2fcaf41c-e494-4806-9e4c-b589da9ddb60']}
# {'event': 'on_chain_stream', 'run_id': '2fcaf41c-e494-4806-9e4c-b589da9ddb60', 'name': '__start__', 'tags': ['graph:step:0', 'langsmith:hidden'], 'metadata': {'langgraph_step': 0, 'langgraph_node': '__start__', 'langgraph_triggers': ('__start__',), 'langgraph_path': ('__pregel_pull', '__start__'), 'langgraph_checkpoint_ns': '__start__:b9f9fe35-1986-2a67-1275-6802f72ceba5'}, 'data': {'chunk': {'messages': ['Hi, how are you?']}}, 'parent_ids': ['9f8df4a1-aa65-4bd2-8a31-0bca8171434e']}
# {'event': 'on_chain_end', 'data': {'output': {'messages': ['Hi, how are you?']}, 'input': {'messages': ['Hi, how are you?']}}, 'run_id': '2fcaf41c-e494-4806-9e4c-b589da9ddb60', 'name': '__start__', 'tags': ['graph:step:0', 'langsmith:hidden'], 'metadata': {'langgraph_step': 0, 'langgraph_node': '__start__', 'langgraph_triggers': ('__start__',), 'langgraph_path': ('__pregel_pull', '__start__'), 'langgraph_checkpoint_ns': '__start__:b9f9fe35-1986-2a67-1275-6802f72ceba5'}, 'parent_ids': ['9f8df4a1-aa65-4bd2-8a31-0bca8171434e']}
# {'event': 'on_chain_start', 'data': {'input': {'messages': [HumanMessage(content='Hi, how are you?', additional_kwargs={}, response_metadata={}, id='6460b041-09ae-4838-a689-e3b93a2532f9')]}}, 'name': 'model', 'tags': ['graph:step:1'], 'run_id': 'b2ed8d9e-d9e4-4dc5-8e9f-abaf861e8527', 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44'}, 'parent_ids': ['9f8df4a1-aa65-4bd2-8a31-0bca8171434e']}
# {'event': 'on_chat_model_start', 'data': {'input': {'messages': [[HumanMessage(content='Hi, how are you?', additional_kwargs={}, response_metadata={}, id='6460b041-09ae-4838-a689-e3b93a2532f9')]]}}, 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'run_id': 'c232aa7c-fa14-44c7-9912-aca3178f1d65', 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9f8df4a1-aa65-4bd2-8a31-0bca8171434e', 'b2ed8d9e-d9e4-4dc5-8e9f-abaf861e8527']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run-c232aa7c-fa14-44c7-9912-aca3178f1d65')}, 'run_id': 'c232aa7c-fa14-44c7-9912-aca3178f1d65', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9f8df4a1-aa65-4bd2-8a31-0bca8171434e', 'b2ed8d9e-d9e4-4dc5-8e9f-abaf861e8527']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='Hello', additional_kwargs={}, response_metadata={}, id='run-c232aa7c-fa14-44c7-9912-aca3178f1d65')}, 'run_id': 'c232aa7c-fa14-44c7-9912-aca3178f1d65', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9f8df4a1-aa65-4bd2-8a31-0bca8171434e', 'b2ed8d9e-d9e4-4dc5-8e9f-abaf861e8527']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='!', additional_kwargs={}, response_metadata={}, id='run-c232aa7c-fa14-44c7-9912-aca3178f1d65')}, 'run_id': 'c232aa7c-fa14-44c7-9912-aca3178f1d65', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9f8df4a1-aa65-4bd2-8a31-0bca8171434e', 'b2ed8d9e-d9e4-4dc5-8e9f-abaf861e8527']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=" I'm", additional_kwargs={}, response_metadata={}, id='run-c232aa7c-fa14-44c7-9912-aca3178f1d65')}, 'run_id': 'c232aa7c-fa14-44c7-9912-aca3178f1d65', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9f8df4a1-aa65-4bd2-8a31-0bca8171434e', 'b2ed8d9e-d9e4-4dc5-8e9f-abaf861e8527']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' here', additional_kwargs={}, response_metadata={}, id='run-c232aa7c-fa14-44c7-9912-aca3178f1d65')}, 'run_id': 'c232aa7c-fa14-44c7-9912-aca3178f1d65', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9f8df4a1-aa65-4bd2-8a31-0bca8171434e', 'b2ed8d9e-d9e4-4dc5-8e9f-abaf861e8527']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='run-c232aa7c-fa14-44c7-9912-aca3178f1d65')}, 'run_id': 'c232aa7c-fa14-44c7-9912-aca3178f1d65', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9f8df4a1-aa65-4bd2-8a31-0bca8171434e', 'b2ed8d9e-d9e4-4dc5-8e9f-abaf861e8527']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' ready', additional_kwargs={}, response_metadata={}, id='run-c232aa7c-fa14-44c7-9912-aca3178f1d65')}, 'run_id': 'c232aa7c-fa14-44c7-9912-aca3178f1d65', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9f8df4a1-aa65-4bd2-8a31-0bca8171434e', 'b2ed8d9e-d9e4-4dc5-8e9f-abaf861e8527']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' to', additional_kwargs={}, response_metadata={}, id='run-c232aa7c-fa14-44c7-9912-aca3178f1d65')}, 'run_id': 'c232aa7c-fa14-44c7-9912-aca3178f1d65', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9f8df4a1-aa65-4bd2-8a31-0bca8171434e', 'b2ed8d9e-d9e4-4dc5-8e9f-abaf861e8527']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' help', additional_kwargs={}, response_metadata={}, id='run-c232aa7c-fa14-44c7-9912-aca3178f1d65')}, 'run_id': 'c232aa7c-fa14-44c7-9912-aca3178f1d65', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9f8df4a1-aa65-4bd2-8a31-0bca8171434e', 'b2ed8d9e-d9e4-4dc5-8e9f-abaf861e8527']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' you', additional_kwargs={}, response_metadata={}, id='run-c232aa7c-fa14-44c7-9912-aca3178f1d65')}, 'run_id': 'c232aa7c-fa14-44c7-9912-aca3178f1d65', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9f8df4a1-aa65-4bd2-8a31-0bca8171434e', 'b2ed8d9e-d9e4-4dc5-8e9f-abaf861e8527']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' with', additional_kwargs={}, response_metadata={}, id='run-c232aa7c-fa14-44c7-9912-aca3178f1d65')}, 'run_id': 'c232aa7c-fa14-44c7-9912-aca3178f1d65', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9f8df4a1-aa65-4bd2-8a31-0bca8171434e', 'b2ed8d9e-d9e4-4dc5-8e9f-abaf861e8527']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' any', additional_kwargs={}, response_metadata={}, id='run-c232aa7c-fa14-44c7-9912-aca3178f1d65')}, 'run_id': 'c232aa7c-fa14-44c7-9912-aca3178f1d65', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9f8df4a1-aa65-4bd2-8a31-0bca8171434e', 'b2ed8d9e-d9e4-4dc5-8e9f-abaf861e8527']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' information', additional_kwargs={}, response_metadata={}, id='run-c232aa7c-fa14-44c7-9912-aca3178f1d65')}, 'run_id': 'c232aa7c-fa14-44c7-9912-aca3178f1d65', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9f8df4a1-aa65-4bd2-8a31-0bca8171434e', 'b2ed8d9e-d9e4-4dc5-8e9f-abaf861e8527']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' or', additional_kwargs={}, response_metadata={}, id='run-c232aa7c-fa14-44c7-9912-aca3178f1d65')}, 'run_id': 'c232aa7c-fa14-44c7-9912-aca3178f1d65', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9f8df4a1-aa65-4bd2-8a31-0bca8171434e', 'b2ed8d9e-d9e4-4dc5-8e9f-abaf861e8527']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' questions', additional_kwargs={}, response_metadata={}, id='run-c232aa7c-fa14-44c7-9912-aca3178f1d65')}, 'run_id': 'c232aa7c-fa14-44c7-9912-aca3178f1d65', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9f8df4a1-aa65-4bd2-8a31-0bca8171434e', 'b2ed8d9e-d9e4-4dc5-8e9f-abaf861e8527']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' you', additional_kwargs={}, response_metadata={}, id='run-c232aa7c-fa14-44c7-9912-aca3178f1d65')}, 'run_id': 'c232aa7c-fa14-44c7-9912-aca3178f1d65', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9f8df4a1-aa65-4bd2-8a31-0bca8171434e', 'b2ed8d9e-d9e4-4dc5-8e9f-abaf861e8527']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' might', additional_kwargs={}, response_metadata={}, id='run-c232aa7c-fa14-44c7-9912-aca3178f1d65')}, 'run_id': 'c232aa7c-fa14-44c7-9912-aca3178f1d65', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9f8df4a1-aa65-4bd2-8a31-0bca8171434e', 'b2ed8d9e-d9e4-4dc5-8e9f-abaf861e8527']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' have', additional_kwargs={}, response_metadata={}, id='run-c232aa7c-fa14-44c7-9912-aca3178f1d65')}, 'run_id': 'c232aa7c-fa14-44c7-9912-aca3178f1d65', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9f8df4a1-aa65-4bd2-8a31-0bca8171434e', 'b2ed8d9e-d9e4-4dc5-8e9f-abaf861e8527']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run-c232aa7c-fa14-44c7-9912-aca3178f1d65')}, 'run_id': 'c232aa7c-fa14-44c7-9912-aca3178f1d65', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9f8df4a1-aa65-4bd2-8a31-0bca8171434e', 'b2ed8d9e-d9e4-4dc5-8e9f-abaf861e8527']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' How', additional_kwargs={}, response_metadata={}, id='run-c232aa7c-fa14-44c7-9912-aca3178f1d65')}, 'run_id': 'c232aa7c-fa14-44c7-9912-aca3178f1d65', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9f8df4a1-aa65-4bd2-8a31-0bca8171434e', 'b2ed8d9e-d9e4-4dc5-8e9f-abaf861e8527']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' can', additional_kwargs={}, response_metadata={}, id='run-c232aa7c-fa14-44c7-9912-aca3178f1d65')}, 'run_id': 'c232aa7c-fa14-44c7-9912-aca3178f1d65', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9f8df4a1-aa65-4bd2-8a31-0bca8171434e', 'b2ed8d9e-d9e4-4dc5-8e9f-abaf861e8527']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' I', additional_kwargs={}, response_metadata={}, id='run-c232aa7c-fa14-44c7-9912-aca3178f1d65')}, 'run_id': 'c232aa7c-fa14-44c7-9912-aca3178f1d65', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9f8df4a1-aa65-4bd2-8a31-0bca8171434e', 'b2ed8d9e-d9e4-4dc5-8e9f-abaf861e8527']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' assist', additional_kwargs={}, response_metadata={}, id='run-c232aa7c-fa14-44c7-9912-aca3178f1d65')}, 'run_id': 'c232aa7c-fa14-44c7-9912-aca3178f1d65', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9f8df4a1-aa65-4bd2-8a31-0bca8171434e', 'b2ed8d9e-d9e4-4dc5-8e9f-abaf861e8527']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' you', additional_kwargs={}, response_metadata={}, id='run-c232aa7c-fa14-44c7-9912-aca3178f1d65')}, 'run_id': 'c232aa7c-fa14-44c7-9912-aca3178f1d65', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9f8df4a1-aa65-4bd2-8a31-0bca8171434e', 'b2ed8d9e-d9e4-4dc5-8e9f-abaf861e8527']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' today', additional_kwargs={}, response_metadata={}, id='run-c232aa7c-fa14-44c7-9912-aca3178f1d65')}, 'run_id': 'c232aa7c-fa14-44c7-9912-aca3178f1d65', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9f8df4a1-aa65-4bd2-8a31-0bca8171434e', 'b2ed8d9e-d9e4-4dc5-8e9f-abaf861e8527']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='?', additional_kwargs={}, response_metadata={}, id='run-c232aa7c-fa14-44c7-9912-aca3178f1d65')}, 'run_id': 'c232aa7c-fa14-44c7-9912-aca3178f1d65', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9f8df4a1-aa65-4bd2-8a31-0bca8171434e', 'b2ed8d9e-d9e4-4dc5-8e9f-abaf861e8527']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f5bdcc3276'}, id='run-c232aa7c-fa14-44c7-9912-aca3178f1d65')}, 'run_id': 'c232aa7c-fa14-44c7-9912-aca3178f1d65', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9f8df4a1-aa65-4bd2-8a31-0bca8171434e', 'b2ed8d9e-d9e4-4dc5-8e9f-abaf861e8527']}
# {'event': 'on_chat_model_end', 'data': {'output': AIMessage(content="Hello! I'm here and ready to help you with any information or questions you might have. How can I assist you today?", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f5bdcc3276'}, id='run-c232aa7c-fa14-44c7-9912-aca3178f1d65'), 'input': {'messages': [[HumanMessage(content='Hi, how are you?', additional_kwargs={}, response_metadata={}, id='6460b041-09ae-4838-a689-e3b93a2532f9')]]}}, 'run_id': 'c232aa7c-fa14-44c7-9912-aca3178f1d65', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9f8df4a1-aa65-4bd2-8a31-0bca8171434e', 'b2ed8d9e-d9e4-4dc5-8e9f-abaf861e8527']}
# {'event': 'on_chain_start', 'data': {'input': {'messages': [AIMessage(content="Hello! I'm here and ready to help you with any information or questions you might have. How can I assist you today?", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f5bdcc3276'}, id='run-c232aa7c-fa14-44c7-9912-aca3178f1d65')]}}, 'name': '_write', 'tags': ['seq:step:2', 'langsmith:hidden'], 'run_id': '3490e2f3-e4ad-46d1-b444-6041ac8ea752', 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44'}, 'parent_ids': ['9f8df4a1-aa65-4bd2-8a31-0bca8171434e', 'b2ed8d9e-d9e4-4dc5-8e9f-abaf861e8527']}
# {'event': 'on_chain_end', 'data': {'output': {'messages': [AIMessage(content="Hello! I'm here and ready to help you with any information or questions you might have. How can I assist you today?", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f5bdcc3276'}, id='run-c232aa7c-fa14-44c7-9912-aca3178f1d65')]}, 'input': {'messages': [AIMessage(content="Hello! I'm here and ready to help you with any information or questions you might have. How can I assist you today?", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f5bdcc3276'}, id='run-c232aa7c-fa14-44c7-9912-aca3178f1d65')]}}, 'run_id': '3490e2f3-e4ad-46d1-b444-6041ac8ea752', 'name': '_write', 'tags': ['seq:step:2', 'langsmith:hidden'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44'}, 'parent_ids': ['9f8df4a1-aa65-4bd2-8a31-0bca8171434e', 'b2ed8d9e-d9e4-4dc5-8e9f-abaf861e8527']}
# {'event': 'on_chain_start', 'data': {'input': {'messages': [HumanMessage(content='Hi, how are you?', additional_kwargs={}, response_metadata={}, id='6460b041-09ae-4838-a689-e3b93a2532f9'), AIMessage(content="Hello! I'm here and ready to help you with any information or questions you might have. How can I assist you today?", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f5bdcc3276'}, id='run-c232aa7c-fa14-44c7-9912-aca3178f1d65')]}}, 'name': 'tools_router', 'tags': ['seq:step:4'], 'run_id': 'ed1357aa-83bc-4f55-b5b5-f8e777876b12', 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44'}, 'parent_ids': ['9f8df4a1-aa65-4bd2-8a31-0bca8171434e', 'b2ed8d9e-d9e4-4dc5-8e9f-abaf861e8527']}
# {'event': 'on_chain_end', 'data': {'output': '__end__', 'input': {'messages': [HumanMessage(content='Hi, how are you?', additional_kwargs={}, response_metadata={}, id='6460b041-09ae-4838-a689-e3b93a2532f9'), AIMessage(content="Hello! I'm here and ready to help you with any information or questions you might have. How can I assist you today?", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f5bdcc3276'}, id='run-c232aa7c-fa14-44c7-9912-aca3178f1d65')]}}, 'run_id': 'ed1357aa-83bc-4f55-b5b5-f8e777876b12', 'name': 'tools_router', 'tags': ['seq:step:4'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44'}, 'parent_ids': ['9f8df4a1-aa65-4bd2-8a31-0bca8171434e', 'b2ed8d9e-d9e4-4dc5-8e9f-abaf861e8527']}
# {'event': 'on_chain_stream', 'run_id': 'b2ed8d9e-d9e4-4dc5-8e9f-abaf861e8527', 'name': 'model', 'tags': ['graph:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44'}, 'data': {'chunk': {'messages': [AIMessage(content="Hello! I'm here and ready to help you with any information or questions you might have. How can I assist you today?", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f5bdcc3276'}, id='run-c232aa7c-fa14-44c7-9912-aca3178f1d65')]}}, 'parent_ids': ['9f8df4a1-aa65-4bd2-8a31-0bca8171434e']}
# {'event': 'on_chain_end', 'data': {'output': {'messages': [AIMessage(content="Hello! I'm here and ready to help you with any information or questions you might have. How can I assist you today?", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f5bdcc3276'}, id='run-c232aa7c-fa14-44c7-9912-aca3178f1d65')]}, 'input': {'messages': [HumanMessage(content='Hi, how are you?', additional_kwargs={}, response_metadata={}, id='6460b041-09ae-4838-a689-e3b93a2532f9')]}}, 'run_id': 'b2ed8d9e-d9e4-4dc5-8e9f-abaf861e8527', 'name': 'model', 'tags': ['graph:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:7f21a5e6-5fb8-be21-1621-91c9dbaeca44'}, 'parent_ids': ['9f8df4a1-aa65-4bd2-8a31-0bca8171434e']}
# {'event': 'on_chain_stream', 'run_id': '9f8df4a1-aa65-4bd2-8a31-0bca8171434e', 'name': 'LangGraph', 'tags': [], 'metadata': {}, 'data': {'chunk': {'model': {'messages': [AIMessage(content="Hello! I'm here and ready to help you with any information or questions you might have. How can I assist you today?", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f5bdcc3276'}, id='run-c232aa7c-fa14-44c7-9912-aca3178f1d65')]}}}, 'parent_ids': []}
# {'event': 'on_chain_end', 'data': {'output': {'messages': [HumanMessage(content='Hi, how are you?', additional_kwargs={}, response_metadata={}, id='6460b041-09ae-4838-a689-e3b93a2532f9'), AIMessage(content="Hello! I'm here and ready to help you with any information or questions you might have. How can I assist you today?", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f5bdcc3276'}, id='run-c232aa7c-fa14-44c7-9912-aca3178f1d65')]}}, 'run_id': '9f8df4a1-aa65-4bd2-8a31-0bca8171434e', 'name': 'LangGraph', 'tags': [], 'metadata': {}, 'parent_ids': []}

# %%
input = {
    "messages": ["Hi, how are you?"]
}

events = app.astream_events(input=input, version="v2")

async for event in events: 
    if event["event"] == "on_chat_model_stream":
        print(event["data"]["chunk"].content, end="", flush=True)
# Out:
# I'm just a virtual assistant, so I don't have feelings, but I'm here and ready to help you! How can I assist you today?
